# %% [markdown]
# <a href="https://colab.research.google.com/github/Laru3e/first-repo/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('STEG.csv')
data
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11       1335667.0
# 1            train_Client_0   2013-03-29          11       1335667.0
# 2            train_Client_0   2015-03-23          11       1335667.0
# 3            train_Client_0   2015-07-13          11       1335667.0
# 4            train_Client_0   2016-11-17          11       1335667.0
# ...                     ...          ...         ...             ...
# 785151  train_Client_121250   2010-12-04          10        405005.0
# 785152  train_Client_121250   2009-10-12          10        405005.0
# 785153  train_Client_121250   2010-04-08          10        405005.0
# 785154  train_Client_121250   2015-02-04          10        405005.0
# 785155  train_Client_121250   2009-04-14          10        405005.0
#
#         counter_statue  counter_code  reading_remarque  counter_coefficient  \
# ...

# %%
client_0_bills = data.head(10)
client_0_bills
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0               0
# 1  train_Client_0   2013-03-29          11       1335667.0               0
# 2  train_Client_0   2015-03-23          11       1335667.0               0
# 3  train_Client_0   2015-07-13          11       1335667.0               0
# 4  train_Client_0   2016-11-17          11       1335667.0               0
# 5  train_Client_0   2017-07-17          11       1335667.0               0
# 6  train_Client_0   2018-12-07          11       1335667.0               0
# 7  train_Client_0   2019-03-19          11       1335667.0               0
# 8  train_Client_0   2011-07-22          11       1335667.0               0
# 9  train_Client_0   2011-11-22          11       1335667.0               0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# ...

# %%
print(type(client_0_bills))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785156 entries, 0 to 785155
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   client_id             785156 non-null  object
#  1   invoice_date          785156 non-null  object
#  2   tarif_type            785156 non-null  int64
#  3   counter_number        785149 non-null  float64
#  4   counter_statue        785156 non-null  int64
#  5   counter_code          785156 non-null  int64
#  6   reading_remarque      784369 non-null  float64
#  7   counter_coefficient   785156 non-null  int64
#  8   consommation_level_1  785156 non-null  int64
#  9   consommation_level_2  785156 non-null  int64
#  10  consommation_level_3  785156 non-null  int64
#  11  consommation_level_4  785156 non-null  int64
#  12  old_index             785156 non-null  int64
#  13  new_index             785156 non-null  int64
# ...

# %%
data.columns
# Out:
# Index(['client_id', 'invoice_date', 'tarif_type', 'counter_number',
#        'counter_statue', 'counter_code', 'reading_remarque',
#        'counter_coefficient', 'consommation_level_1', 'consommation_level_2',
#        'consommation_level_3', 'consommation_level_4', 'old_index',
#        'new_index', 'months_number', 'counter_type'],
#       dtype='object')

# %%
print("shape(rows, columns):", data.shape)
# Out:
# shape(rows, columns): (785156, 16)

# %%
categorical_feature = data.select_dtypes(include= ['object', 'category']).columns
print(list(categorical_feature))
# Out:
# ['client_id', 'invoice_date', 'counter_type']

# %%
print(len(categorical_feature))
# Out:
# 3

# %%
data.columns
# Out:
# Index(['client_id', 'invoice_date', 'tarif_type', 'counter_number',
#        'counter_statue', 'counter_code', 'reading_remarque',
#        'counter_coefficient', 'consommation_level_1', 'consommation_level_2',
#        'consommation_level_3', 'consommation_level_4', 'old_index',
#        'new_index', 'months_number', 'counter_type'],
#       dtype='object')

# %%
print("memory usage=", round(data.memory_usage(deep=True).sum()))
# Out:
# memory usage= 222651915

# %%
missen_value = data.isnull().sum()
missen_value
# Out:
# client_id                 0
# invoice_date              0
# tarif_type                0
# counter_number            7
# counter_statue            0
# counter_code              0
# reading_remarque        787
# counter_coefficient       0
# consommation_level_1      0
# consommation_level_2      0
# consommation_level_3      0
# consommation_level_4      0
# old_index                 0
# new_index                 0
# months_number             0
# counter_type              0
# dtype: int64

# %%
x = data.columns[data.isnull().any()]
x
# Out:
# Index(['counter_number', 'reading_remarque'], dtype='object')

# %%
##missing values

for col in data.columns:
  if data[col].isnull().sum() > 0:
    if data[col].dtype in ['float64', 'int64']:
      data[col].fillna(data[col].median(), inplace= True)
    else:
      data[col].fillna(data[col].mode()[0], inplace= True)
print('missing values after handling:', data.isnull().sum())
# Out:
# missing values after handling: client_id               0
# invoice_date            0
# tarif_type              0
# counter_number          0
# counter_statue          0
# counter_code            0
# reading_remarque        0
# counter_coefficient     0
# consommation_level_1    0
# consommation_level_2    0
# consommation_level_3    0
# consommation_level_4    0
# old_index               0
# new_index               0
# months_number           0
# counter_type            0
# dtype: int64
# /tmp/ipykernel_5642/1129246390.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# mode was used for categorical data while median was used for continous or numeric data

# %%
data.describe()
# Out:
#           tarif_type  counter_number  counter_statue   counter_code  \
# count  785156.000000    7.851560e+05   785156.000000  785156.000000
# mean       20.130974    1.184475e+11        0.042211     172.276689
# std        13.475638    1.627848e+12        0.374716     133.537298
# min         8.000000    0.000000e+00        0.000000       5.000000
# 25%        11.000000    1.225030e+05        0.000000       5.000000
# 50%        11.000000    4.928500e+05        0.000000     203.000000
# 75%        40.000000    1.111436e+06        0.000000     207.000000
# max        45.000000    2.738110e+13        5.000000     600.000000
#
#        reading_remarque  counter_coefficient  consommation_level_1  \
# count     785156.000000        785156.000000         785156.000000
# mean           7.320358             1.000316            409.125733
# std            1.360239             0.095986            575.516993
# min            6.000000             0.000000              0.000000
# ...

# %%
client0_method1 = data[data['client_id'] == 'train_Client_0']
client0_method1
# Out:
#          client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0   train_Client_0   2014-03-24          11       1335667.0               0
# 1   train_Client_0   2013-03-29          11       1335667.0               0
# 2   train_Client_0   2015-03-23          11       1335667.0               0
# 3   train_Client_0   2015-07-13          11       1335667.0               0
# 4   train_Client_0   2016-11-17          11       1335667.0               0
# 5   train_Client_0   2017-07-17          11       1335667.0               0
# 6   train_Client_0   2018-12-07          11       1335667.0               0
# 7   train_Client_0   2019-03-19          11       1335667.0               0
# 8   train_Client_0   2011-07-22          11       1335667.0               0
# 9   train_Client_0   2011-11-22          11       1335667.0               0
# 10  train_Client_0   2008-11-25          11       1335667.0               0
# ...

# %%
client0_method2 = data.loc[data['client_id'] == 'train_Client_0']
client0_method2
# Out:
#          client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0   train_Client_0   2014-03-24          11       1335667.0               0
# 1   train_Client_0   2013-03-29          11       1335667.0               0
# 2   train_Client_0   2015-03-23          11       1335667.0               0
# 3   train_Client_0   2015-07-13          11       1335667.0               0
# 4   train_Client_0   2016-11-17          11       1335667.0               0
# 5   train_Client_0   2017-07-17          11       1335667.0               0
# 6   train_Client_0   2018-12-07          11       1335667.0               0
# 7   train_Client_0   2019-03-19          11       1335667.0               0
# 8   train_Client_0   2011-07-22          11       1335667.0               0
# 9   train_Client_0   2011-11-22          11       1335667.0               0
# 10  train_Client_0   2008-11-25          11       1335667.0               0
# ...

# %%
encoder = LabelEncoder()
data['encoded'] = encoder.fit_transform(data['counter_type'])
data['encoded'].unique()
# Out:
# array([0, 1])

# %%
data['counter_type'].unique()
# Out:
# array(['ELEC', 'GAZ'], dtype=object)

# %%
data = data.drop(data['counter_type'])
